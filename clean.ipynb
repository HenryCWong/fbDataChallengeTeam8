# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.plotly as py
import plotly.graph_objs as go

sns.set()

# %%
df = pd.read_csv("sf_business_cleaned.csv")
# Out:
# C:\Users\cywon\newAnaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning:
#
# Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
df.head()
# Out:
#    owner_number  business_number  location_number         owner_name  \
# 0          28.0                1                1    Ferrando Louise
# 1          52.0                1                1   Ideal Novak Corp
# 2          71.0                1                1  Tournahu George L
# 3          71.0                2                1  Tournahu George L
# 4          71.0                3                1  Tournahu George L
#
#                business_name         street_address           city state  \
# 0           3101 Laguna Apts         3101 Laguna St  san francisco    CA
# 1           Ideal Novak Corp          8 Mendosa Ave  san francisco    CA
# 2              Tournahu Arms      1842 Jefferson St  san francisco    CA
# 3  3301 Broderick Apartments      3301 Broderick St  san francisco    CA
# 4       1840-42 Jefferson St  1840 Jefferson St #42  san francisco    CA
#
#    zipcode                   latlong        neighborhood business_start  \
# ...

# %%
df["city"].unique()
# Out:
# array(['san francisco', 'hayward', 'redwood city', ..., 'hartford',
#        "san 'francisco", 'elk groove'], dtype=object)

# %%
df["business_end"].unique().shape
# Out:
# (3379,)

# %%
end = df.dropna(subset=['business_end'])

# %%
end
# Out:
#         owner_number  business_number  location_number  \
# 5               86.0                1                1
# 6               86.0                2                1
# 44             422.0                1                1
# 47             429.0                1                1
# 54             484.0                1                1
# 55             553.0                1                1
# 111           1219.0                1                1
# 112           1219.0                2                1
# 113           1219.0                3                1
# 114           1219.0                4                1
# 125           1335.0                1                1
# 134           1520.0                1                1
# 135           1520.0                2                1
# 147           1818.0                1                1
# 148           1818.0                2                1
# 155           2142.0                1                1
# ...

# %%
endNaics = end["naics_code"].value_counts()

# %%
allNaics = df["naics_code"].value_counts()

# %%
newdf = pd.DataFrame()

# %%
newdf["endNaics"] = endNaics

# %%
newdf["allNaics"] = allNaics

# %%
newdf.head()
# Out:
#                                                   endNaics  allNaics
# Professional, Scientific, and Technical Services      3271     22230
# Transportation and Warehousing                        3248      6178
# Real Estate and Rental and Leasing Services           2258     23861
# Construction                                          2211     14727
# Food Services                                         2041     10685

# %%
newdf["percentages"] = newdf["endNaics"] / newdf["allNaics"]

# %%
newdf.head()
# Out:
#                                                   endNaics  allNaics  \
# Professional, Scientific, and Technical Services      3271     22230
# Transportation and Warehousing                        3248      6178
# Real Estate and Rental and Leasing Services           2258     23861
# Construction                                          2211     14727
# Food Services                                         2041     10685
#
#                                                   percentages
# Professional, Scientific, and Technical Services     0.147143
# Transportation and Warehousing                       0.525736
# Real Estate and Rental and Leasing Services          0.094631
# Construction                                         0.150132
# Food Services                                        0.191015

# %%
df.sort_values(by=['percentages'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-2ad48c61c7d0> in <module>
# ----> 1 df.sort_values(by=['percentages'])
#
# ~\newAnaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4419             by = by[0]
#    4420             k = self._get_label_or_level_values(by, axis=axis,
# -> 4421                                                 stacklevel=stacklevel)
#    4422
#    4423             if isinstance(ascending, (tuple, list)):
#
# ~\newAnaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis, stacklevel)
#    1380             values = self.axes[axis].get_level_values(key)._values
#    1381         else:
# -> 1382             raise KeyError(key)
#    1383
#    1384         # Check for duplicates
#
# KeyError: 'percentages'
